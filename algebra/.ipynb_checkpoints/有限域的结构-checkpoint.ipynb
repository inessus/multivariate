# %% [markdown]
# 本节我们将证明有限域的三条结构定理，它们是
#
# **定理1** 设$F$是有限域并设$F$的特征是$p$，那么$F$的元素个数一定是$p$的一个幂
#
# **定理2** 设$p$是任意一个素数而n是任意一正整数，那么总存在一个恰含$q^n$个元素的有限域
#
# **定理3** 任意两个元素个数相同的有限域一定同构

# %% [markdown]
# ## 5.1 定理1 证明
#
# 我们先来证明定理1的一个推广，它包含有定理1作为特例
#
# **定理4** 设$F$是个有限域，它包含有一个$q$个元素的有限域$F_q$作为子域，那么$F$的元素个数一定是$q$的幂
#
# **证明** 将$F_q$改记成$F_1$，如果$F=F_1$，那么$F$就是恰含$q$个元素的有限域，因此这时定理4成立，如果$F\neq F_1$，那么$F$就还有一个元素$e_2$，而$e_2\not\in F_1$，令$$F_2=\{a_1 + a_2e_2\|a_1,a_2 \in F_1\}$$。我们证明：如果$$a_1+a_2e_2=b_1+b_2e_2, \quad a_1,a_2,b_1,b_2 \in F_1$$那么一定有$a_1=_b1,a_2=b_2$,实际上，从上式推出$$(a_2-b_2)e_2=b_1-a_1$$
# 如果$a_2 \not \in b_2$,那么$$e_2=(a_2-b_2)^{-1}(b_1-a_1) \in F_1$$
# 这是一个矛盾，因此一定有$a_2=b_2$，于是也有$a_1=b_1$，因此可以推出$F_2$恰含$q^2$个两两不同的元素。
#
# 如果$F=F_2$，那么$F$就是恰含$q^2$个元素的有限域，因此这时定理4成立，如果$F\neq F_2$，那么$F$就还有一个元素$e_3$，而$e_3\not\in F_2$，令$$F_3=\{a_1 + a_2e_2+a_3e_3\|a_1,a_2,a_3 \in F_1\}$$。假定有$$a_1+a_2e_2+a_3e_3=b_1+b_2e_2+b_3e_3, \quad a_i,b_i\in F_1$$那么一定有$a_1=_b1,a_2=b_2, a_3=b_3$,实际上，从上式推出$$(a_3-b_3)e_3=(b_1-a_1)+(b_2-a_2)e_2$$
# 如果$a_3 \neq b_3$,那么$$e_3=(a_3-b_3)^{-1}(b_1-a_1)+(a_3-b_3)^{-1}(b_2-a_2)e_2 \in F_2$$
# 这是一个矛盾，因此一定有$a_3=b_3$，于是也有$a_1+a_2e_2=b_1+b_2e_2$，再根据上一段的证明可知$a_1=b_1,a_2=b_2$,于是可以推出$F_3$恰含$q^3$个两两不同的元素。
#
# 如果$F=F_3$，那么$F$就是恰含$q^3$个元素的有限域，因此这时定理4成立，如果$F\neq F_3$，那么$F$就还有一个元素$e_4$，而$e_4\not\in F_3$，令$$F_4=\{a_1 + a_2e_2+a_3e_3+a_4e_4\|a_1,a_2,a_3,a_4 \in F_1\}$$。仿上可证$F_4$恰含$q^4$个两两不同的元素。
#
# 如此进行嫁娶如果$F$的元素个数是$N$，而$q^n\leq N < q^{n+1}$那么我们得到F的一串子集$$F_1,F_2,F_3,\dots,F_n$$
# 其中$$F_i={a_1+a_2e_2+\dots+a_ie_i\|a_1,a_2,\dots,a_i \in F_1}$$而$$e_2\not\in F_1, e_3\not\in F_2, \dots, e_n\not\in F_{n-1}$$
# 同时$F_i(i\leq i \leq n)$恰有$q^i$个两两不同的元素，如果$F\neq F_n$，那么$F$就含有一个元素$e_{n+1},e_{n+1}\not\in F_n$，令
# $$F_{n+1}={a_1+a_2e_2+\dots+a_ne_n+a_{n+1}e_{n+1}\|a_1,a_2, \dots, a_n,a_{n+1}\in F_1}$$
# 仿上可证$F_{n+1}$恰含$q^{n+1}$个两两不同的元素，但$F_{n+1}$是$F$的子集，而$F$的元素个数$N<q^{n+1}$所以这是不能能的，因此一定有$F=F_n$，于是F是恰含$q^n$个元素的有限域，这就证明了定理4。
#
# 从定理4立刻推导出定理1，设$F$是有限域，并设$F$的特征是$p$,那么$p$一定是一个素数，而$F$的素域$\it{\Pi}$就是恰含$p$个元素的有限域，在定理4中取$F_q=\it{\Pi}$就得出定理1

# %% [markdown]
# ## 5.2 定理2证明
# 为了证明定理2，只需要证明:对任一素数$p$和任一正整数n,$ Z_p[x] $中总有一个n次不可约多项式即可。因为如果$f(x)$是$Z_p[x]$中的一个n次不可约多项式，那么在$\$2$中构造的域$Z_p[x]_{f(x)}$就是一个$p^n$个元素的有限域。下面我们将求出任一有限域上n次不可约多项式的一个明显公式，然后再利用这个公式推出这个个数一定$ \geq 1$，特别，我们就证明了$Z_p[x]$中总有n次不可约多项式的存在。
#
# 需要首先做些准备：
#
# ### 5.2.1 引理1
# 设$F$是个有限域，而$F_{q}$是$F$的一个含$q$个元素的子域,那么$F_q$中的元素$\alpha$都适合条件$\alpha^q=\alpha$，更进一步，如果$F$中有一个元素$\beta$适合条件$\beta^q=\beta$,那么$\beta \in F_q$
#
# **证明**: 根据$\$4$定理5，我们知道$F_q^*$是$q-1$阶循环群，设$\zeta$是他的一个生成元，那么
# $$\zeta^0=e,\zeta^1=\zeta,\zeta^2,\dots,\zeta^{q-2}$$
# 就是$F_q^*$的全部$q-1$个元素，显然有$$(\zeta^i)^{q-1}=(\zeta^{q-1})^i=e^i=e, \quad 0 \leq i\leq q-2$$
# 将上式两端同乘以$\zeta^i$，就有$$(\zeta^i)^q=\zeta^i, \quad 0\leq i \leq q-2$$
# 这就是说, $F_q$中任一元素$\alpha$（包括0）都适合条件$\alpha^q=\alpha$,这样一来，多项式$$x^q-x$$
# 就是以$F_q$中的$q$个元素为它的全部根，将$x^q-x$看做$F$上的多项式，它在$F$中顶多有$q$个根，因此如果有$\beta(\in F)$是多项式的根，即$\beta^q-\beta=0$,那么一定有$\beta \in F_q$
#
# ### 5.2.2 引理2
# 设$F_q$是$q$个元素的一个有限域，而$f(x)$是$F_q[x]$中的一个n次不可约多项式，那么一定有$$f(x)\mid(x^{q^n}-x)$$
#
# **证明**： 令$$F_q[x]_{f(x)} = \{a_0+a_1x+a_2x^2+\dots+a_{n-1}x^{n-1}\|a_0,a_1,a_2,\dots,a_{n-1} \in F_q\}$$
# 在$\$2$中已经在$F_q[x]_{f(x)}$中规定了加法和乘法运算，即对任一$a(x), b(x) \in F_q[x]_{f(x)}$规定
# $$a(x)\oplus b(x)=a(x)+b(x)$$
# $$a(x)\odot b(x)=(a(x)b(x))_{f(x)}$$
# 我们也证明了$F_q[x]_{f(x)}$按如上规定的加法和乘法运算是一个域，而且是一个含$q^n$个元素的域，根据引理1，$F_q[x]_{f(x)}$中的元素$\alpha$都适合$\alpha^{q^n}=x$，即$\alpha^{q^n}-x=0$ 特别的，$x\in F_q[x]_{f(x)}$，因此在$F_q[x]_{f(x)}$中$x^{q^n}-x=0$,而这实际上是$$ \underbrace{x\odot x\odot \dots \odot x}_{q^n}-x=0,$$
# 即$$(x^{q^n})_{f(x)}-x=0$$
# 但根据$\$2$定理1的推论有$$(x^{q^n}-x)_{f(x)}=(x^{q^n})_{f(x)}-x$$
# 因此$$(x^{q^n}-x)_{f(x)}=0$$
# 这就是说$$f(x)\mid(x^{q^n}-x)$$
#
# ### 5.2.3 引理3
# 设$F_q$是q个元素的一个有限域，而$f(x)$是$F_q[x]$中的一个m次不可约多项式，如果$m > n $，那么一定有$$f(x)\nmid(x^{q^n}-x)$$
# **证明**: 用反证法，设$f(x)\mid(x^{q^n}-x)$,这就是说$(x^{q^n}-x)_{f(x)} = 0$那么$$(x^{q^n})_{f(x)}=x$$
# 因 $degf(x)=m, $所以$F_q[x]_{f(x)}$是$q^m$个元素的有限域，又因$F_q$是$F_q[x]_{f(x)}$的子域，所以$q$一定是$F_q[x]_{f(x)}$的特征（也是$F_q$的特征）的一个米，那么对于$F_q[x]_{f(x)}$中任意一个元素
# $$g(x) = \sum_{i=0}^{m-1}{a_ix^i}, \quad a_i \in F_q$$
# 都有$$\underbrace{g(x)\odot g(x)\odot\dots \odot g(x)}_{q^n}-g(x)$$
# $$(g(x)^{q^n})_{f(x)}-g(x)$$
# $$=\left( \sum_{i=0}^{m-1}{a_i^{q^n}x^{iq^n}}\right)_{f(x)} - \sum_{i=0}^{m-1}{a_ix^i}$$
# $$=\sum_{i=0}^{m-1}{a_i(((x^{q^n})_{f(x)})^i)_{f(x)}} - \sum_{i=0}^{m-1}{a_ix^i}$$
# $$=\sum_{i=0}^{m-1}{a_ix^i}-\sum_{i=0}^{m-1}a_ix^i=0$$
# 这就是说$F_q[x]_{f(x)}$中$q^m$个元素都适合多项式
# $$X^{q^n}-X$$
# 但$m>n$，因此根据$\$2$定理5的推论2,这是不可能的，根多出来了，这就证明了引理3
#
# ### 5.2.4 引理4
# 设m，n是正整数，而$d=gcd(m,n)$,那么
# $$gcd(x^m-e, x^n-e)=x^d-e$$
# **证明** 对$max\{m,n\}$用归纳法，当$m=n$时，本引理显然成立，设$m>n$那么
# $$gcd(x^m-e, x^n-e)=gcd(x^m-e-x^{m-n}(x^n-e), x^n-e)$$
# $$=gcd(x^{m-n}-e, x^n-e)$$
# 但$max{m-n,n}<m = max{m,n}, 而gcd(m-n, n)=gcd(m,n)=d$所以根据归纳法假设有
# $$gcd(x^{m-n}-e, x^n-e)=x^d-e$$
# 因此
# $$gcd(x^m-e, x^n-e)=x^d-e$$
#
# ### 5.2.5 引理5
# 设m，n是正整数，而$d = gcd(m, n)$那么$$gcd(x^{q^m}-x, x^{q^n}-x)=x^{q^d}-x$$
# **证明** 仿照引理4的证明，可证$$gcd(q^m-1, q^n-1)=q^d-1$$
# 那么根据引理4，有
# $$gcd(x^{q^m-1}-e, x^{q^n-1}-e)=x^{q^d-1}-e$$
# 因此$$gcd(x^{q^m}-x, x^{q^n}-x)=x^{q^d}-x$$
#
# ### 5.2.6 引理6
# 设$F_q$是一个q个元素的有限域，而$f(x)$是$F_q[x]$中的一个d次不可约多项式，那么$f(x)\mid(x^{q^n}-x)$当且仅当$d\mid n$
# **证明**: 根据引理2， $$f(x)\mid (x^{q^d}-x)$$
# 如果$d\mid n$，则$gcd(d, n) = d$，根据引理5，
# $$gcd(x^{q^d}-x, x^{q^n}-x)=(x^{q^d}-x)$$
# 于是$$f(x)\mid gcd(x^{q^d}-x, x^{q^n}-x),$$
# 因此$$f(x)\mid (x^{q^n}-x)$$
# 反之，设$$f(x)\mid (x^{q^n}-x)$$
# 那么$$f(x)\mid gcd(x^{q^n}-x, x^{q^d}-x)$$
# 令$$d^{'}=gcd(n, d)$$根据引理5就有
# $$f(x)\mid (x^{q^{d^{'}}}-x)$$
# 在根据引理3， $d^{'}\geq d$但$d^{'}=gcd(n, d)\leq d$因此$d^{'}=d$，于是$d\mid n$
#
# ### 5.2.7 引理7
# 设$F_q$是一个q个元素的有限域，那么对于任意正整数n， $x^{q^n}-x$都没有重因式
#
# **证明**: 令$$f(x) = x^{q^n-1}-e$$
# 那么 $$f^{'}(x)=(q^n-1)x^{q^n-2}$$
# 设$F_q$的特征为p，根据定理1，q是p的一个幂，设$q=p^m$,那么
# $$gcd(q^n-1, p)=gcd(p^{mn}-1, p)=1$$
# 因此$f^{'}(x)\neq 0$,但$f^{'}(x)$只有x及$cx(c\in F_q)$为其因式，而$x\nmid f(x)$, 因此
# $$gcd(f(x), f^{'}(x))=e$$
# 那么根据$\$2$定理4，$x^{q^n-1}-e$没有重因式，又显然x不是$x^{q^n-1}-e$的因式，因而$x^{q^n-1}-e$也没有重因式
#
# ### 5.2.8 定理5
#
# 有了以上这些准备，我们先来证明定理5
#
# **定理5** 设$F_q$是一个q个元素的有限域，n是一个正整数，而$p_1, p_2, \dots, p_m$是n个所有两两不同的素因数，用$\Phi_{q,n}(x)$表示$F_q[x]$中所有首项式系数是e的n次不可约多项式的乘积，那么$$\Phi_{q,n}(x)=(x^{q^n}-x)\prod_{i=1}^{m}(x^{q^{n/p_i}}-x)^{-1}\prod_{i \leq i<j\leq m}{(x^{q^{n/{p_ip_j}}}-x)}\prod_{1\leq i<j<k\leq m}{(x^{q^{n/{p_ip_jp_k}}}-x)}\dots(x^{q^{n/{p_1p_2\dots p_m}}}-x)$$
# 再用$\mid\Phi_{q,n}(x)\mid$表示$F_q[x]$中首项式系数是e的n次不可约多项式的个数，那么
# $$\mid \Phi_{q,n}(x)\mid=\frac{1}{n}\left( q^n-\sum_{i=1}^{m}q^{n/p_i} + \sum_{1\leq < j \leq m}q^{n/{p_ip_j}}-\sum_{i\leq i < j <k\leq m}q^{n/{p_ip_jp_k}}+\dots+(-1)^nq^{n/{p_1p_2\dots p_m}} \right)$$
#
# **证明** 在引理7里已经证明$x^{q^n}-x$没有重因子，因此根据$2定理$x^{q^n}-x$可以分解成$F_q[x]$中一些两两不同的首项系数是e的不可约多项式的乘积。
#
# 再根据引理6可知，$x^{q^n}-x$是$F_q[x]$中所有次数是n的因数的首项式系数是e的不可约多项式的乘积，为了从$x^{q^n}-x$得到$\Phi_{q,n}(x)$，需要从$x^{q^n}-x$中除去所有次数是$n/p_1$，或$n/p_2,\dots,$ 或$n/p_m$的因数的首项系数是e的不可约多项式。仍根据引理6，次数是$n/p_i$的因数的首项系数是e的不可约多项式的乘积正好是$x^{q^{n/p_i}}-x(1\leq i \leq m)$但从$x^{q^n}-x$除去$\prod_{i=1}{m}(x^{q^{n/p_i}}-x)$之后，在$$(x^{q^n}-x)\prod_{i=1}^{m}(x^{q^{n/p_i}}-x)^{-1}$$
# 中次数是$\frac{n}{p_ip_j}(i\leq i < j \leq m)$的首项式系数是e的不可约多项式却被除了两次，故又需添上，但在添上$\prod_{1\leq i < j \leq m}(x^{q^{n/p_ip_j}}-x)$之后，在
# $$(x^{q^n}-x)\prod_{i=1}^{n}(x^{q^{n/p_i}}-x)^{-1}\prod_{i\leq i < j \leq m}(x^{q^{n/p_ip_j}}-x)$$
# 中，以$\frac{n}{p_ip_jp_k}(1\leq i < j < k \leq m)$的因数为次数的首项式系数是e的不可约多项式先被除去了3次，后又添上了$\begin{pmatrix} 3 \\ 2 \end{pmatrix} = 3$次，故仍需除去，如此继续下去，即得式
