# %% [markdown]
# # 主成分
# ## 8.1 引言
# 主成分分析所关心的问题，是通过一组变量的几个线性组合来解释这组变量的方差-协方差结构，它的一般目的是
# 1. 数据的压缩
# 2. 数据的解释
#
# ## 8.2 总体主成分
# 主成分，在代数学上是p个随机变量$X_1, X_2, \dots, X_p$的一个特殊的线性组合，而在几何学上，这些线性组合代表选取一个新坐标系，它是以$X_1, X_2, \dots, X_p$为坐标轴的原坐标系旋转后得到的。新坐标轴代表数据变异性最大的方向，并且提供对协方差结构的一个较为简单但更精炼的刻画。
#
# 我们看到主成分只依赖于$X_1, X_2, \dots, X_p$的协方差军阵$\Sigma$(或相关矩阵$\rho$),它们的进一步讨论不需要做多元正态假定。另一方面，对于多元正态总体导出的主成分可以使用常数密度椭球来作有用的阐述，进而，当总体是多元正态时，可由样本分量做出推断。
# 设随机向量$X^{'}=[X_1, X_2, \dots, X_p]$有协方差矩阵$\Sigma$，其特征值$\lambda_1 \geq \lambda_2 \geq \dots \geq \lambda_p \geq 0$
# 考虑线性组合
# $$Y_1=a_1^{'}X = a_{11}X_1+a_{12}X_2+\dots+a_{1p}X_p$$
# $$Y_2=a_2^{'}X = a_{21}X_1+a_{22}X_2+\dots+a_{2p}X_p$$
# $$\vdots$$
# $$Y_p=a_p^{'}X = a_{p1}X_1+a_{p2}X_2+\dots+a_{pp}X_p$$
# 我们得到
# $$Var(Y_1)=a^{'}_i\Sigma a_i  \qquad i = 1,2,\dots, p$$
# $$Cov(Y_1,Y_k)=a^{'}_i\Sigma a_k  \qquad i,k = 1,2,\dots, p$$
# 主成分是那些不线性相关的线性组合$Y_i, Y_1, \dots, Y_p$，它们能使上式方差尽可能大。
# 设$\Sigma$是随机向量$X^{'} = X_1, X_2, \dots, X_p$的协方差矩阵，它有特征值和特征向量对$(\lambda_1, e_1),(\lambda_2, e_2),\dots,(\lambda_p, e_p)$,其中$\lambda_1 \geq \lambda_2 \geq \dots \geq \lambda_p \geq 0$，则第i个主成分由
# $$Y_i=e_{i}^{'}X=e_{i1}X_1+e_{i2}X_2+\dots+e_{ip}X_p, \qquad i=1,2, \dots, p$$
# 此时$$Var(Y_i)=e^{'}_i\Sigma e_i = \lambda_i \qquad i = 1,2,\dots, p$$
# $$Cov(Y_i,Y_k)=e^{'}_i\Sigma e_k = 0 \qquad i \not= k$$
#
#
# 如果$Y_1=e_1^{'}X, Y_2=e_2^{'}X, \dots, Y_p=e_p^{'}X$从协方差矩阵$\Sigma$所得到的主成分，则$$\rho_{Y_i,X_k}=\frac{e_{ik}\sqrt{\lambda_i}}{\sqrt{\sigma_{kk}}} \qquad i,k=1,2,\dots,p$$是成分$Y_i$和变量$X_k$之间的相关系数，此处$(\lambda_1, e_1),(\lambda_2, e_2),\dots,(\lambda_p, e_p)$是$\Sigma$的特征值-特征向量对
#
# ### 从标准化变量得到主成分
# 主成分也可以从标准化变量$$Z_i=\frac{X_1-\mu_1}{\sqrt{\sigma_{11}}}$$
# $$Z_2=\frac{X_2-\mu_2}{\sqrt{\sigma_{22}}}$$
# $$\vdots$$
# $$Z_p=\frac{X_p-\mu_p}{\sqrt{\sigma_{pp}}}$$
# 采用矩阵记号
# $$Z=\left(V^{1/2}\right)^{-1}(X-\mu)$$
# 其中E(Z) =0 且$$Cov(Z)=(V^{1/2})^{-1}\Sigma(V^{1/2})^{-1} = \rho$$
#
# ### 有特殊结构的协方差矩阵的主成分
# 存在某些结构的协方差和相关矩阵，它们的主成分能够表示成简单的形式，设$\Sigma$是对角矩阵
# $$\Sigma = \begin{bmatrix} \sigma_{11} & 0 & \dots & 0 \\ 0 & \sigma_{22}  & \dots & 0  \\ \vdots & \vdots & \ddots &\vdots \\ 0 & 0 & \dots & \sigma_{pp}\end{bmatrix}$$
# 令$e_i^{'}=[0,\dots,0, 1, 0, \dots, 0]$，第i个位置上为1我们看到
# $$\Sigma = \begin{bmatrix} \sigma_{11} & 0 & \dots & 0 \\ 0 & \sigma_{22}  & \dots & 0  \\ \vdots & \vdots & \ddots &\vdots \\ 0 & 0 & \dots & \sigma_{pp}\end{bmatrix} \begin{bmatrix}  0 \\ \vdots \\ 0 \\ 1 \\ 0 \\ \vdots \\ 0 \end{bmatrix}=\begin{bmatrix}  0 \\ \vdots \\ 0 \\ 1\sigma_{ii} \\ 0 \\ \vdots \\ 0 \end{bmatrix} \qquad 或 \qquad \Sigma e_i=\sigma_{ii}e_i$$ 并得到结论: $(\sigma_{ii}, e_i)$是第i个特征值-特征向量对
#
#
# 另一种模式的协方差矩阵常用于描述诸如生物大小等生态学变量中的对应关系，这种矩阵的一般形式为:
# $$\Sigma = \begin{bmatrix} \sigma^2 & \rho\sigma^2 & \dots & \rho\sigma^2 \\ \rho\sigma^2 & \sigma^2  & \dots & \rho\sigma^2  \\ \vdots & \vdots & \ddots &\vdots \\ \rho\sigma^2 & \rho\sigma^2 & \dots & \sigma^2\end{bmatrix}$$
# 得到的相关矩阵为
# $$\boldsymbol{\rho} = \begin{bmatrix} 1 & \rho & \dots & \rho \\ \rho & 1  & \dots & \rho  \\ \vdots & \vdots & \ddots &\vdots \\ \rho & \rho & \dots & 1\end{bmatrix}$$
# 也是标准化变量的协方差矩阵，而且表明变量$X_1, X_2, \dots, X_p$是等相关的。
# 相关矩阵p个特征值可以分为两组，当p为正时，最大特征值为
# $$\lambda_1 = 1 + (\rho-1)\rho$$
# 相关的特征向量为
# $$e_1^{'}=\left[\frac{1}{\sqrt{p}},\frac{1}{\sqrt{p}},\dots, \frac{1}{\sqrt{p}}\right]$$
# 其余p-1个特征向量是$$\lambda_2=\lambda_3=\dots=\lambda_p  =1- \rho$$
# 它们的特征向量可以选为:
# $$e_2^{'}=\left[\frac{1}{\sqrt{1\times2}},\frac{-1}{\sqrt{1\times2}},0,\dots,0\right]$$
# $$e_3^{'}=\left[\frac{1}{\sqrt{2\times3}},\frac{1}{\sqrt{2\times3}},\frac{-2}{\sqrt{2\times3}},\dots,0\right]$$
# $$\vdots \qquad \vdots$$
# $$e_i^{'}=\left[\frac{1}{\sqrt{(i-1)i}},\dots,\frac{1}{\sqrt{(i-1)i}},\frac{-(i-1)}{\sqrt{(i-1)i}},0,\dots,0\right]$$
# $$\vdots \qquad \vdots \qquad \vdots$$
# $$e_p^{'}=\left[\frac{1}{\sqrt{(p-1)p}},\dots,\frac{1}{\sqrt{(p-1)p}},\frac{-(p-1)}{\sqrt{(p-1)p}}\right]$$
# 第一主成分$$Y_i=e_1^{'}Z=\frac{1}{\sqrt{p}}\sum_{i=1}^{p}Z_i$$

# %% [markdown]
# ## 8.3 综合主成分的样本变差
# 若$S=\{s_{ik}\}$是特征值-特征向量对为$(\hat{\lambda}_1, \hat{e}_1),(\hat{\lambda}_2, \hat{e}_2),\dots, (\hat{\lambda}_p, \hat{e}_p)$的$p\times p$样本协方差，则第i个样本主成分由
# $$\hat{y}_i=\hat{e}_i^{'}\mathop{x}=\hat{e}_{i1}x_1+\hat{e}_{i2}x_2+\dots+\hat{e}_{ip}x_p \qquad i = 1, 2, \dots, p$$
# 给出，其中$\hat{\lambda}_1 \geq \hat{\lambda}_2 \geq \dots \geq \hat{\lambda}_p \geq 0$，而x是变量$X_1,X_2,\dots,X_p$的任意观察，同时还有$$样本方差 \quad (\hat{y}_k)=\hat{\lambda}_k, \quad k=1,2,\dots,p$$
# $$样本协方差 \quad (\hat{y}_i, \hat{y}_k)=0,\quad k = 1,2,\dots,p$$ 此外
# $$样本总方差 = \sum^{p}_{i=1}=\hat{\lambda}_1 + \hat{\lambda}_2 + \dots + \hat{\lambda}_p$$
# 且
# $$\hat{r}_{y_i,x_k}=\frac{\hat{e}_{ik}\sqrt{\hat{\lambda}_i}}{\sqrt{s_{kk}}} \quad i,k = 1,2,\dots,p$$
#
# ### 主成分个数
# 一个能帮助我们确定主成分合适个数的有用的视觉工具，是所谓的崖底碎石图。将特征从大到小排列，崖底碎石图就是$\hat{\lambda}_i$对序号i的图。为确定主成分的合适个数，我们在改图上找拐弯处(弯曲处)，选取一个拐弯点对应的序号，此序号后的特征值全部较小且彼此差不多，这样选出的号码数作为主成分的个数。
# ```python
# def scree_plot():
#     pass
# ```
#
# ### 样本主成分解释
# 样本主成分有几种解释，首先设X的真实分布接近$N_p(\mu, \Sigma)$，此时样本主成分$\hat{y}_i=\hat{e}_k^{'}(x-\overline{x})$是总体主成分$Y_i=e_i^{i}(X-\mu)$的一个实现，后者服从$N_p(\mathop{0},\Lambda)$分布，对角阵$\Lambda$有主对角元$\lambda_1,\lambda_2,\dots,\lambda_p$，而$(\lambda,e)$是$\Sigma$的特征值-特征向量对
#
#
# 利用样本值$x_j$我们也可以用$\overline{x}$近似$\mu$而S近似$\Sigma$，若S正定，则所有满足$$(x-\overline{x})^{1}S^{-1}(x-\overline{x})  = c^2$$的$p\times 1$向量x所组成的等值轮廓线，估计出真实的正态密度的常数密度等值轮廓线$(x-\overline{x})^{1}S^{-1}(x-\overline{x}) = c^2$。为显示生成数据的正态分布，可以把这些近似的等值轮廓线绘制到散布图上。
#
#
# 样本主成分在几何学上的解释，$\dots$
#
# ### 样本主成分的标准化
# 一般来说，样本主成分在尺度改变时不是不变的，正如我们在总体成分处理中提到的，在不同尺度或者在同一尺度但变化范围极其不同时所测量的变量，常常要标准化，例如，下述构造完成标准化：$$z_j=D^{-1/2}(x_j-\overline{x})=\begin{bmatrix}\frac{x_{j1}-\overline{x}_1}{\sqrt{s_{11}}} \\ \frac{x_{j2}-\overline{x}_2}{\sqrt{s_{22}}} \\ \dots \\ \frac{x_{jp}-\overline{x}_p}{\sqrt{s_{pp}}} \end{bmatrix} \qquad j = 1,2,\dots, n$$
# 将观测值标准化后的$x\times p $数据矩阵
# $$Z = \begin{bmatrix}z_1^{'} \\ z_2^{'} \\ \dots \\ z_n^{'}\end{bmatrix} = \begin{bmatrix}z_{11} & z_{12} & \dots & z_{1p} \\ z_{21} & z_{22} & \dots & z_{2p} \\ \vdots & \vdots & \ddots & \vdots \\ z_{n1} & z_{n2} & \dots & z_{np}  \end{bmatrix}$$
# $$\qquad$$
# $$=\begin{bmatrix}\frac{x_{11}-\overline{x}_1}{\sqrt{s_{11}}} & \frac{x_{12}-\overline{x}_2}{\sqrt{s_{22}}} & \dots & \frac{x_{1p}-\overline{x}_p}{\sqrt{s_{pp}}} \\ \frac{x_{21}-\overline{x}_1}{\sqrt{s_{11}}} & \frac{x_{22}-\overline{x}_2}{\sqrt{s_{22}}} & \dots & \frac{x_{2p}-\overline{x}_p}{\sqrt{s_{pp}}} \\ \vdots & \vdots & \ddots & \vdots \\ \frac{x_{n1}-\overline{x}_1}{\sqrt{s_{11}}} & \frac{x_{n2}-\overline{x}_2}{\sqrt{s_{22}}} & \dots & \frac{x_{np}-\overline{x}_p}{\sqrt{s_{pp}}}  \end{bmatrix} \tag{1-1}$$
#
# $\heartsuit$

# %% [markdown]
# ## 8.4主成分的图形表示
# 主成分的图形表示出了能核查正态性假定，还能揭示可疑的观测值，由于主成分是原变量的线性组合，因此期望它们是近似正态不是没有道理。当要把前几个主成分作为输入数据而做补充时，常常必须确认它们近似是正态的。
#
#
# 最后几个主成分能帮助去人可以的观测值，各个观测值可以表达成S的全部特征向量$\hat{e}_1,\hat{e}_2,\dots,\hat{e}_p$的线性组合
# $$x_j = (x_j^{'}\hat{e}_1)\hat{e}_1+(x_j^{'}\hat{e}_2)\hat{e}_2+\dots+(x_j^{'}\hat{e}_p)\hat{e}_p$$
# $$=\hat{y}_{j1}\hat{e}_1+\hat{y}_{j2}\hat{e}_2+\dots+\hat{y}_{jp}\hat{e}_p$$
# 这样后几个主成分的大小就可以决定前几个主成分你和观测值的好坏程度，这就是说$\hat{y}_{j1}\hat{e}_1+\hat{y}_{j2}\hat{e}_2+\dots+\hat{y}_{jp}\hat{e}_p$

# %% [markdown]
# ## 8.5大样本推断
# 我们已经看到，协方差矩阵的特征值和特征向量是主成分分析的精髓。特征向量决定最大变异方向，而特征值说明方差。当前几个特征值比余下的大得多时，总方差的大部分在低于p维空间里得到“解释”。
#
#
# 实际上，必须在从S或者从R中抽取的特征值-特征向量$(\hat{\lambda}_i, \hat{e}_i)$的基础上，去做出认定主成分近似特性的决定，因为抽样的变异，这些特征值和特征向量会与潜在的总体的特征值和特征向量有差别。推导$\hat{\lambda}_i$和$\hat{e}_i$的抽样分布是困难的，也超出本书的范围。可参考对多元正态总体的某些推断。
# * Anderson,T.W. An Introduction to Multivariate Statistical Analysis(3rd ed.). New York: John Wiley, 2003.
# * Anderson,T.W. "Asymptotic Theory for Principal Components Analysis" Annals of Mathematical Statistics, 34(1963).122-148
# * Grischick, M. "On the Sampling Theory of Roots of Determinantal Equations" Annals of Mathematical Statistics, 10(1939),417-441, 498-520
#
# ### $\hat{\lambda}_i$和$\hat{e}_i$大样本的性质
# 目前得到的涉及$\hat{\lambda}_i$和$\hat{e}_i$的大样本置信区间的结论，都假设观测值$X_1, X_2, \dots, X_n$是正态总体的随机样本，还必须假设$\Sigma$的特征值不同且皆为正，故$\lambda_1 > \lambda_2 > \dots  >\lambda_p > 0$,一个例外是当相等特征值的个数是已知的时候，处分存在强烈的理由相信$\Sigma$具有产生相等特征值的特殊结构，否则我们采用的结论通常都是针对不同的特征值的情况，及时违背了正态性的假定，用该方法得到的置信区间仍能为$\hat{\lambda}_i$和$\hat{e}_i$的不确定性提供信息。
#
#
# Anderson 和 Grischick已经对S的特征值$\hat{\lambda}^{'} = [\hat{\lambda}_1, \dots, \hat{\lambda}_p]$和特征向量$\hat{e}_1,\dots,\hat{e}_p$,建立了下列大样本分布理论：
# 1. 令$\Lambda$是$\Sigma$的特征值$\lambda_1,\dots, \lambda_p$的对角矩阵，则$\sqrt{n}(\hat{\lambda}-\lambda)$近似的服从分布$N_p(0,2\Lambda^2)$
# 2. 令$E_i = \lambda_i\sum_{k=1,k\neq i}^{p}\frac{\lambda_k}{(\lambda_k-\lambda_i)^2}e_ke_k^{'}$ 则$\sqrt{n}(\hat{e}_i-e_i)$近似服从$N_p(0,E_i)$
#
#
# ### 等相关结构的检验
# 特殊的相关结构$Cov(X_i,X_k) = \sqrt{\sigma_{ii}\sigma_{kk}}\rho$或者$Corr(X_i, X_k)=\rho$是一个重要结构，此时$\Sigma$特征值是不同的，因此先前的结论不适用。
#
#
# $\dots$

# %% [markdown]
# ## 8.6 用主成分监控质量
# 第五章我们介绍了多元控制图，包括质量椭圆图和$T^2$图，本章将开展类似的讨论
# ### 检查一组已知测量值的稳定性
# 令$X_1, X_2, \dots, X_n$是从均值$\mu$，协方差矩阵$\Sigma$的正态分布中抽取的随机样本，我们考虑前两个样本主成分，$\hat{y_{j1}}=\hat{e}_1^{'}(x_j-\overline{x})和\hat{y_{j2}}=\hat{e}_2^{'}(x_j-\overline{x})$,在任何两个成分中，前两个都解释样本总方差最大的积累比。
#
# 如果一个过程在全部时间里都是稳定的，只由于共同原因引起的变化影响所测量的特征，那么在这种情况下，前两个主成分的值应该都是稳定的，反之，如果主成分保持全时稳定，那么影响该过程的共同因素有希望保持常数。为了用主成分监控质量，我们分两步考虑过程，
#
# 第一步构造一个数值对$(\hat{y}_{j1},\hat{y}_{j2})(j=1,2,\dots,n)$,第一主成分$\hat{y}_1$的样本方差由最大特征值$\hat{\lambda}_1$给出，第二主成分$\hat{\lambda}_2$的样本方差由第二大特征值$\hat{\lambda}_2$给出，两个样本主成分是不相关的，故对大的n，质量椭圆为满足下列条件的可能的所有数值对$(\hat{y}_{j1},\hat{y}_{j2})$的点集:
# $$\frac{\hat{y}_1^2}{\hat{\lambda}_1} + \frac{\hat{y}_2^2}{\hat{\lambda}_2} \leq \chi_2^2(\alpha)$$
#
# 第二步 由椭圆形式图里不曾包含到的主成分的信息生成。考虑离差向量$X-\mu$，并假设X为N_p(\mu, \Sigma)分布，即便没有正态性假定，$X_j-\mu$也可表达为它在$\Sigma$的特征向量的投影之和
# $$X-\mu = (X-\mu)^{'}e_1e_1+(X-\mu)^{'}e_2e_2 + \dots + (X-\mu)'e_pe_p$$
# 或
# $$X-\mu = Y_1e_1+Y_2e_2+\dots+Y_pe_p$$去掉两个主成分统计量变为
# $$T_j^2=\frac{\hat{y}_{j3}^2}{\hat{\lambda}_3}+\frac{\hat{y}_{j4}^2}{\hat{\lambda}_4} + \dots + \frac{\hat{y}_{jp}^2}{\hat{\lambda}_p}$$
# 生成一个$T_2$图，令上限$UCL=c^2=\chi_{p-2}^2(\alpha)$
#
# ### 控制未来值
# $\dots$
